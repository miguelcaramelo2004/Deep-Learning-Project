# %% [markdown]
# Imports

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# Retirar os dados e dividir por pastas

# %%
DATASET_PATH = "dataset/wikiart"
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# Found 13340 files belonging to 23 classes.
# Using 10672 files for training.
# Found 13340 files belonging to 23 classes.
# Using 2668 files for validation.

# %%
class_names = train_ds.class_names
num_classes = len(class_names)

# %% [markdown]
# Ideia do Chat para otimizar a pipeline

# %% [markdown]
# Resultado:
#
# menos tempo parado
#
# treino mais rápido

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# NN básica

# %%
model = keras.Sequential([
    layers.Rescaling(1./255),

    layers.Flatten(),

    layers.Dense(128, activation="relu"),
    layers.Dense(64, activation="relu"),

    layers.Dense(num_classes, activation="softmax")
])

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])

# %%
model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)
# Out:
# Epoch 1/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step - accuracy: 0.0602 - loss: 7.0072 - val_accuracy: 0.0663 - val_loss: 3.1034
# Epoch 2/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 12s 37ms/step - accuracy: 0.0750 - loss: 3.0765 - val_accuracy: 0.0660 - val_loss: 3.0595
# Epoch 3/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.0878 - loss: 3.0466 - val_accuracy: 0.1019 - val_loss: 3.0463
# Epoch 4/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.0985 - loss: 3.0412 - val_accuracy: 0.1016 - val_loss: 3.0446
# Epoch 5/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.0985 - loss: 3.0407 - val_accuracy: 0.1016 - val_loss: 3.0445
# Epoch 6/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.0985 - loss: 3.0407 - val_accuracy: 0.1016 - val_loss: 3.0440
# Epoch 7/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.0985 - loss: 3.0407 - val_accuracy: 0.1016 - val_loss: 3.0437
# Epoch 8/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.0985 - loss: 3.0408 - val_accuracy: 0.1016 - val_loss: 3.0440
# Epoch 9/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.0985 - loss: 3.0407 - val_accuracy: 0.1016 - val_loss: 3.0438
# Epoch 10/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.0974 - loss: 3.0407 - val_accuracy: 0.1016 - val_loss: 3.0440

# %% [markdown]
# Data Augmentation

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# %% [markdown]
# Normalization

# %%
normalization_layer = layers.Rescaling(1./255)

# %% [markdown]
# Simple CNN Model

# %%
model = keras.Sequential([
    data_augmentation,
    normalization_layer,

    layers.Conv2D(32, 3, activation="relu"),
    layers.MaxPooling2D(),

    layers.Conv2D(64, 3, activation="relu"),
    layers.MaxPooling2D(),

    layers.Conv2D(128, 3, activation="relu"),
    layers.MaxPooling2D(),

    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.3),

    layers.Dense(num_classes, activation="softmax")
])

# %% [markdown]
# Compile

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# Training

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)
# Out:
# Epoch 1/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 104s 307ms/step - accuracy: 0.1883 - loss: 2.8110 - val_accuracy: 0.2496 - val_loss: 2.5540
# Epoch 2/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 106s 317ms/step - accuracy: 0.2689 - loss: 2.5024 - val_accuracy: 0.3238 - val_loss: 2.3304
# Epoch 3/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 105s 314ms/step - accuracy: 0.3124 - loss: 2.3274 - val_accuracy: 0.3178 - val_loss: 2.2984
# Epoch 4/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 100s 300ms/step - accuracy: 0.3490 - loss: 2.2087 - val_accuracy: 0.3373 - val_loss: 2.1961
# Epoch 5/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 98s 294ms/step - accuracy: 0.3760 - loss: 2.1161 - val_accuracy: 0.3538 - val_loss: 2.1676
# Epoch 6/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 97s 290ms/step - accuracy: 0.3951 - loss: 2.0462 - val_accuracy: 0.4010 - val_loss: 1.9969
# Epoch 7/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 97s 290ms/step - accuracy: 0.4143 - loss: 1.9764 - val_accuracy: 0.3943 - val_loss: 2.1200
# Epoch 8/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 97s 291ms/step - accuracy: 0.4328 - loss: 1.8951 - val_accuracy: 0.4123 - val_loss: 1.9771
# Epoch 9/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 97s 289ms/step - accuracy: 0.4483 - loss: 1.8329 - val_accuracy: 0.3868 - val_loss: 2.0752
# Epoch 10/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 97s 291ms/step - accuracy: 0.4581 - loss: 1.8026 - val_accuracy: 0.4303 - val_loss: 1.9303

# %% [markdown]
# Teste rápido

# %%
for images, labels in train_ds.take(1):
    preds = model(images)
    print("Output shape:", preds.shape)
# Out:
# Output shape: (32, 23)
# 2026-03-23 10:59:40.868330: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
